# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, utils
import numpy as np
import datetime

import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
train_dataset = utils.image_dataset_from_directory(
'./chest_xray/train',
image_size=(480, 480),
color_mode='grayscale',
batch_size=16)

val_dataset = utils.image_dataset_from_directory(
'./chest_xray/val',
image_size=(480, 480),
color_mode='grayscale',
batch_size=16)

test_dataset = utils.image_dataset_from_directory(
'./chest_xray/test',
image_size=(480, 480),
color_mode='grayscale',
batch_size=16)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
data_augmentation = keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
    
])

# %%
inputs = keras.Input(shape=(480, 480 ,1))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128 ,256, 512]:
    residual = x
    
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(size, 3, padding='same', use_bias=False)(x)
    
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(size, 3, padding='same', use_bias=False)(x)

    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)
    
    residual = layers.Conv2D(size, 1, strides=2, padding='same', use_bias=False)(residual)
    x = layers.add([x, residual])
    
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 480, 480, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 480, 480, 1)  0           ['input_1[0][0]']
#
#  rescaling (Rescaling)          (None, 480, 480, 1)  0           ['sequential[0][0]']
#
#  conv2d (Conv2D)                (None, 476, 476, 32  800         ['rescaling[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 476, 476, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 476, 476, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 476, 476, 32  1312       ['activation[0][0]']
#  v2D)                           )
#
#  batch_normalization_1 (BatchNo  (None, 476, 476, 32  128        ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 476, 476, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 476, 476, 32  1312       ['activation_1[0][0]']
#  onv2D)                         )
#
#  max_pooling2d (MaxPooling2D)   (None, 238, 238, 32  0           ['separable_conv2d_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 238, 238, 32  1024        ['conv2d[0][0]']
#                                 )
#
#  add (Add)                      (None, 238, 238, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 238, 238, 32  128        ['add[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 238, 238, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  separable_conv2d_2 (SeparableC  (None, 238, 238, 64  2336       ['activation_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_3 (BatchNo  (None, 238, 238, 64  256        ['separable_conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 238, 238, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  separable_conv2d_3 (SeparableC  (None, 238, 238, 64  4672       ['activation_3[0][0]']
#  onv2D)                         )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 119, 119, 64  0          ['separable_conv2d_3[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 119, 119, 64  2048        ['add[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 119, 119, 64  0           ['max_pooling2d_1[0][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 119, 119, 64  256        ['add_1[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 119, 119, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  separable_conv2d_4 (SeparableC  (None, 119, 119, 12  8768       ['activation_4[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_5 (BatchNo  (None, 119, 119, 12  512        ['separable_conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 119, 119, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  separable_conv2d_5 (SeparableC  (None, 119, 119, 12  17536      ['activation_5[0][0]']
#  onv2D)                         8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 128)  0          ['separable_conv2d_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 60, 60, 128)  8192        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 60, 60, 128)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 60, 60, 128)  512        ['add_2[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 60, 60, 128)  0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 60, 60, 256)  33920      ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 60, 60, 256)  1024       ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 60, 60, 256)  0           ['batch_normalization_7[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 60, 60, 256)  67840      ['activation_7[0][0]']
#  onv2D)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 256)  0          ['separable_conv2d_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 30, 30, 256)  32768       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 30, 30, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 30, 30, 256)  1024       ['add_3[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 30, 30, 256)  0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 30, 30, 512)  133376     ['activation_8[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 30, 30, 512)  2048       ['separable_conv2d_8[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 30, 30, 512)  0           ['batch_normalization_9[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 30, 30, 512)  266752     ['activation_9[0][0]']
#  onv2D)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 512)  0          ['separable_conv2d_9[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 15, 15, 512)  131072      ['add_3[0][0]']
#
#  add_4 (Add)                    (None, 15, 15, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 512)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1)            513         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 720,257
# Trainable params: 717,249
# Non-trainable params: 3,008
# __________________________________________________________________________________________________

# %%
model.compile(loss="binary_crossentropy", optimizer='rmsprop', metrics=['accuracy'])

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=3),
    keras.callbacks.ModelCheckpoint(
        filepath='my_best_ckpt.keras',
        save_best_only=True,
        monitor='val_loss'),
    keras.callbacks.TensorBoard(
        log_dir='./full_log_dir/' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),
        histogram_freq=1,
        embeddings_freq=1, 
        update_freq=1)
]

# %%
import os 

if os.path.isfile('./my_best_ckpt.keras') is True:
    pass
else:
    history = model.fit(train_dataset, epochs=30, validation_data=val_dataset, callbacks=callbacks_list)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 326/326 [==============================] - 54s 147ms/step - loss: 0.3239 - accuracy: 0.8495 - val_loss: 1.7167 - val_accuracy: 0.5000
# Epoch 2/30
# 326/326 [==============================] - 48s 148ms/step - loss: 0.2635 - accuracy: 0.8838 - val_loss: 0.9372 - val_accuracy: 0.5625
# Epoch 3/30
# 326/326 [==============================] - 48s 147ms/step - loss: 0.2326 - accuracy: 0.8955 - val_loss: 1.4681 - val_accuracy: 0.6250
# Epoch 4/30
# 326/326 [==============================] - 48s 147ms/step - loss: 0.2058 - accuracy: 0.9124 - val_loss: 1.6744 - val_accuracy: 0.5000
# Epoch 5/30
# 326/326 [==============================] - 48s 146ms/step - loss: 0.1887 - accuracy: 0.9229 - val_loss: 0.8778 - val_accuracy: 0.8750
# Epoch 6/30
# 326/326 [==============================] - 48s 148ms/step - loss: 0.1755 - accuracy: 0.9289 - val_loss: 0.3222 - val_accuracy: 0.7500
# Epoch 7/30
# 326/326 [==============================] - 48s 146ms/step - loss: 0.1606 - accuracy: 0.9385 - val_loss: 0.5175 - val_accuracy: 0.8125
# Epoch 8/30
# 326/326 [==============================] - 48s 146ms/step - loss: 0.1546 - accuracy: 0.9390 - val_loss: 0.1833 - val_accuracy: 0.9375
# Epoch 9/30
# 326/326 [==============================] - 48s 147ms/step - loss: 0.1393 - accuracy: 0.9459 - val_loss: 1.5379 - val_accuracy: 0.7500
# Epoch 10/30
# 326/326 [==============================] - 48s 146ms/step - loss: 0.1359 - accuracy: 0.9488 - val_loss: 0.4635 - val_accuracy: 0.8125
# Epoch 11/30
# 326/326 [==============================] - 49s 149ms/step - loss: 0.1431 - accuracy: 0.9454 - val_loss: 0.8449 - val_accuracy: 0.5000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, "bo", label="training accuracy")
plt.plot(epochs, val_acc, "b", label="validation accuracy")
plt.title("Trainin and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "bo", label="training loss")
plt.plot(epochs, val_loss, "b", label="validation loss")
plt.title("Trainin and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model('my_best_ckpt.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 39/39 [==============================] - 1s 32ms/step - loss: 0.3074 - accuracy: 0.8798
# 테스트 정확도: 0.880

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir './full_log_dir' --bind_all
# Out:
#       <iframe id="tensorboard-frame-1bc05b2e76e30b8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1bc05b2e76e30b8");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
img1 = keras.preprocessing.image.load_img('./chest_xray/test/NORMAL/IM-0023-0001.jpeg', target_size=(480,480), color_mode='grayscale')
img2 = keras.preprocessing.image.load_img('./chest_xray/test/PNEUMONIA/person3_virus_17.jpeg', target_size=(480,480), color_mode='grayscale')

# %%
x1 = keras.preprocessing.image.img_to_array(img1)
x1 = np.expand_dims(x1, axis=0)
x1 = layers.Rescaling(1./255)(x1)

# %%
x2 = keras.preprocessing.image.img_to_array(img2)
x2 = np.expand_dims(x2, axis=0)
x2 = layers.Rescaling(1./255)(x2)

# %%
y_pred = model.predict(x1)
# Out:
# 1/1 [==============================] - 0s 299ms/step

# %%
print(y_pred)
# Out:
# [[0.9999994]]

# %%
last_conv_layer = model.get_layer('conv2d_5')

# %%
model_1= keras.Model(model.inputs, last_conv_layer.output)

# %%
input_2 = keras.Input(shape=last_conv_layer.output.shape[1:])
x_2 = model.get_layer("global_average_pooling2d")(input_2)
x_2 = model.get_layer("dense")(x_2)
model_2=keras.Model(input_2,x_2)

# %%
#GradientTape함수를 이용한 그레디언트 계산
with tf.GradientTape() as tape:
    output_1 = model_1(x1)
    tape.watch(output_1) #마지막 층으로 미분하기 위한 준비
    preds = model_2(output_1)
    class_id = tf.argmax(preds[0])
    output_2 = preds[:,class_id]

grads = tape.gradient(output_2, output_1) #그레디언트 계산
pooled_grads = tf.reduce_mean(grads,axis=(0,1,2)) #전역 평균 풀링 적용

output_1 = output_1.numpy()[0]
pooled_grads = pooled_grads.numpy()
for i in range(pooled_grads.shape[-1]):
    output_1[:,:,i]*=pooled_grads[i]
heatmap=np.mean(output_1, axis=-1)

heatmap =np.maximum(heatmap, 0)/np.max(heatmap) #정규화
plt.matshow(heatmap)

plt.show()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
#열지도를 입력 영상에 씌움
img = keras.preprocessing.image.load_img('./chest_xray/test/NORMAL/IM-0023-0001.jpeg') #입력 영상을 다시 받음

img = keras.preprocessing.image.img_to_array(img)
heatmap=np.uint8(255*heatmap) # [0,255]로 변환

jet = cm.get_cmap("jet") #jet 컬러맵으로 표시
color = jet(np.arange(256))[:,:3]
color_heatmap = color[heatmap]

color_heatmap = keras.preprocessing.image.array_to_img(color_heatmap)
color_heatmap = color_heatmap.resize((img.shape[1], img.shape[0]))
color_heatmap = keras.preprocessing.image.img_to_array(color_heatmap)

overlay_img= color_heatmap*0.4+img #덧씌움
overlay_img = keras.preprocessing.image.array_to_img(overlay_img)
plt.matshow(overlay_img)

plt.show()

# %% [markdown]
# 결과 : 환자의 흉곽 영역에 빨갛게 표시하는 것을 보아 GradCAM이 의사결정 한는것을 확인할 수 있다.
